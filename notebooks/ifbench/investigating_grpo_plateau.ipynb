# %%
# investigate api score on the training set.

# %%
import json
with open('data/ifbench/input_train_data_with_claude_response_5000_subset.jsonl', 'r') as f:
    data = [json.loads(line) for line in f.readlines() if line.strip()]
len(data)
# Out:
# 5000

# %%
success_count = 0

for x in data:
    if x['claude_reward']: 
        success_count += 1

success_count
# Out:
# 1677

# %%
# evaluate using the system prompt.
